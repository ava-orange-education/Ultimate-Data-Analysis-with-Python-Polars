# %%
import polars as pl

# Creating a DataFrame with List and Struct columns
df = pl.DataFrame({
    "names": [["Aarav", "Ishaan", "Raghav"], ["Saanvi", "Ananya"], ["Vivaan"]],
    "addresses": [
        {"street": "12 MG Road", "city": "Delhi", "zipcode": "110001", "country": "India"},
        {"street": "22 Abbey Road", "city": "London", "zipcode": "W1A 1AA", "country": "UK"},
        {"street": "56 Park Avenue", "city": "New York", "zipcode": "10016", "country": "USA"}
    ]
})

print(df)
# Out:
# shape: (3, 2)
# ┌───────────────────────────────┬─────────────────────────────────┐
# │ names                         ┆ addresses                       │
# │ ---                           ┆ ---                             │
# │ list[str]                     ┆ struct[4]                       │
# ╞═══════════════════════════════╪═════════════════════════════════╡
# │ ["Aarav", "Ishaan", "Raghav"] ┆ {"12 MG Road","Delhi","110001"… │
# │ ["Saanvi", "Ananya"]          ┆ {"22 Abbey Road","London","W1A… │
# │ ["Vivaan"]                    ┆ {"56 Park Avenue","New York","… │
# └───────────────────────────────┴─────────────────────────────────┘
