# %%
import polars as pl

# Creating a DataFrame with Integer and Float columns
df = pl.DataFrame({
    "ages": [25, 30, 35, 40],         # Integer column
    "heights": [5.8, 6.0, 5.5, 5.9]   # Float column
})

# Printing the DataFrame
print(df)
# Out:
# shape: (4, 2)
# ┌──────┬─────────┐
# │ ages ┆ heights │
# │ ---  ┆ ---     │
# │ i64  ┆ f64     │
# ╞══════╪═════════╡
# │ 25   ┆ 5.8     │
# │ 30   ┆ 6.0     │
# │ 35   ┆ 5.5     │
# │ 40   ┆ 5.9     │
# └──────┴─────────┘
